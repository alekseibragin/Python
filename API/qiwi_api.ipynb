# %%
import getpass
import requests
import json

from SimpleQIWI import *

token = "..........."         
phone = "+79........"

api = QApi(token=token, phone=phone)


# Используйте api.full_balance чтобы получить больше информации о кошельках. {'serviceName': 'payment-history', 'errorCode': 'auth.forbidden', 'description': 'Access denied', 'userMessage': 'Access denied', 'dateTime': '2020-11-11', 'traceId': ''} 


print(api.balance)
# Out:
# [8698.6]

# %%
print(api.full_balance)
# Out:
# [{'type': {'id': 'WALLET', 'title': 'Visa QIWI Wallet'}, 'balance': {'amount': 8698.6, 'currency': 643}}]

# %%
print(api.payments)
# Out:
# <built-in method values of dict object at 0x10ae77500>

# %%
#А так можно получить платежи и посмотреть id человека
#------------------------------------------
# номер кошелька в формате +79992223344

#mylogin = '+79.......'

# пароль от кошелька
#mypassword = getpass.getpass('Password:')

#def get_tgt_ticket(my_login,my_password):
#    s = requests.Session()
#    header = {'content-type': 'application/json',
#          'X-Requested-With':'XMLHttpRequest',
#          'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/56.0.2924.87 Safari/537.36'
#         }
#    s.headers=header
#    r = s.post('https://auth.qiwi.com/cas/tgts', json = {'login':mylogin,'password':mypassword})
#    tgt_Ticket = json.loads(r.text)['entity']['ticket']
#    return tgt_Ticket

#tgtTicket = get_tgt_ticket(mylogin,mypassword)
